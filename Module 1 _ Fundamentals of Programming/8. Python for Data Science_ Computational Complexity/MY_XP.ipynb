# %%
#1binary search
import numpy as np
import random

# %%
l = list(range(100))
random.shuffle(l)

l
# Out:
# [93,
#  20,
#  11,
#  98,
#  54,
#  25,
#  24,
#  94,
#  30,
#  19,
#  81,
#  41,
#  88,
#  16,
#  91,
#  84,
#  61,
#  57,
#  26,
#  62,
#  13,
#  28,
#  95,
#  4,
#  3,
#  85,
#  79,
#  49,
#  58,
#  37,
#  36,
#  68,
#  32,
#  46,
#  42,
#  34,
#  8,
#  17,
#  69,
#  27,
#  90,
#  55,
#  72,
#  51,
#  76,
#  38,
#  5,
#  52,
#  74,
#  65,
#  66,
#  40,
#  86,
#  63,
#  89,
#  15,
#  39,
#  60,
#  10,
#  83,
#  50,
#  0,
#  12,
#  45,
#  87,
#  80,
#  77,
#  14,
#  21,
#  53,
#  31,
#  9,
#  7,
#  67,
#  56,
#  29,
#  1,
#  75,
#  78,
#  96,
#  99,
#  97,
#  73,
#  71,
#  22,
#  6,
#  59,
#  23,
#  47,
#  2,
#  92,
#  48,
#  44,
#  18,
#  64,
#  35,
#  70,
#  82,
#  33,
#  43]

# %%
#sequentialsearch
#o(n) Time   
#o(1) space   
q = 31
isFound = False;
for ele in l:
    if ele ==31:
        print("FOUND")
        isFound = True
        break;
if isFound ==False:
    print("NOT FOUND")
# Out:
# FOUND

# %% [markdown]
# #2
# #Binary search
# #O(Log₂ n)
# #Things we need to do Binary search
# """
# 1.The list must be sorted.
# 2.L=M=R
#
#   find 25
# """

# %%
import math
def binarySearch(arry,l,r,x):

    #Check Base Case
    if r >=l:
        mid = l + math.floor((r-l)/2)

        #if Element is present at the middle itself
        if arry[mid]== x:
            return mid
        
        #if element is smaller than mid ,then it can only be present in the left subarray
        elif arry[mid] > x:
            return binarySearch(arry,l,mid-1,x)
        
        #else the element can only be present in the right subarray
        else: 
            return binarySearch(arry,mid+1,r,x)
    else:
        #element is not present in the array
        return -1
    
l.sort();
arr = l;
q = 31;
binarySearch(arry,0,len(arr)-1,q)
# Out:
# 31

# %%
# Find element common in two lists:
l1 = list(range(100))
random.shuffle(l1)

l2 = list(range(50))
random.shuffle(l2)

#find common elements : O(n*m)

cnt=0;
for i in l1:
    for j in l2:
        if i==j:
            print(i)
            cnt += 1;
print("Number of common elements:", cnt)
# Out:
# 42
# 35
# 13
# 40
# 44
# 31
# 26
# 47
# 41
# 12
# 37
# 34
# 0
# 38
# 7
# 30
# 21
# 5
# 20
# 16
# 2
# 19
# 25
# 24
# 28
# 18
# 36
# 49
# 46
# 39
# 23
# 33
# 43
# 9
# 22
# 6
# 27
# 11
# 4
# 29
# 45
# 15
# 10
# 3
# 48
# 17
# 8
# 32
# 14
# 1
# Number of common elements: 50

# %%
l1 = list(range(100))
random.shuffle(l1)

l2 = list(range(70))
random.shuffle(l2)

cnt=0;
for i in l1:
    for j in l2:
        if i==j:
            print(i)
            cnt +=1;
print("nom of element:",cnt)
# Out:
# 11
# 21
# 26
# 48
# 47
# 24
# 6
# 34
# 68
# 17
# 57
# 31
# 67
# 36
# 55
# 30
# 7
# 38
# 35
# 51
# 56
# 4
# 53
# 32
# 23
# 61
# 62
# 5
# 15
# 22
# 39
# 37
# 2
# 54
# 46
# 63
# 49
# 40
# 44
# 18
# 14
# 9
# 42
# 65
# 20
# 8
# 0
# 16
# 64
# 41
# 27
# 69
# 50
# 12
# 43
# 58
# 59
# 29
# 25
# 28
# 52
# 33
# 60
# 66
# 19
# 1
# 10
# 3
# 45
# 13
# nom of element: 70

# %%
#4. Find elements common in two lists using a Hashtable or Dict-

# %%
l1 = list(range(100))
random.shuffle(l1)
 
l2 = list(range(50))
random.shuffle(l2)

#find common elements in list in O(n) time and O(m) space if m<n

##add all elements in the smallest list into a hashtable/Dict: O(m) space

smallList = {}
for ele in l2:
    smallList[ele] = 1; #any value is ok .Key is important

#now find common elements

cnt=0;
for i in l1:
    if smallList.get(i) != None: #search happens in constant time.
        print(i);
        cnt += 1;
print("number of common elements :",cnt)
# Out:
# 31
# 16
# 13
# 36
# 11
# 28
# 29
# 4
# 0
# 24
# 26
# 49
# 21
# 25
# 5
# 3
# 40
# 8
# 1
# 22
# 6
# 37
# 32
# 34
# 46
# 23
# 45
# 12
# 15
# 38
# 9
# 19
# 20
# 14
# 18
# 43
# 48
# 17
# 2
# 42
# 39
# 30
# 44
# 27
# 7
# 33
# 41
# 35
# 47
# 10
# number of common elements : 50
